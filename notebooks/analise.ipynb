# %% [markdown]
# # Aula 1: Analisando os primeiros dados
#
# Durante a aula foi passado essa base de dados sobre algum experimento.

# %%
import pandas as pd
dados_exp_url =  '../dados/dados_experimentos.zip'
dados = pd.read_csv(dados_exp_url, compression = 'zip')
dados
# Out:
#                  id    tratamento  tempo dose      droga     g-0     g-1  \
# 0      id_000644bb2     com_droga     24   D1  b68db1d53  1.0620  0.5577
# 1      id_000779bfc     com_droga     72   D1  df89a8e5a  0.0743  0.4087
# 2      id_000a6266a     com_droga     48   D1  18bb41b2c  0.6280  0.5817
# 3      id_0015fd391     com_droga     48   D1  8c7f86626 -0.5138 -0.2491
# 4      id_001626bd3     com_droga     72   D2  7cbed3131 -0.3254 -0.4009
# ...             ...           ...    ...  ...        ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  df1d0a5a1  0.1394 -0.0636
# 23810  id_fffb70c0c     com_droga     24   D2  ecf3b6b74 -1.3260  0.3478
# 23811  id_fffc1c3f4  com_controle     48   D2  cacb2b860  0.3942  0.3756
# 23812  id_fffcb9e7c     com_droga     24   D1  8b87a7a83  0.6660  0.2324
# 23813  id_ffffdd77b     com_droga     72   D1  972f41291 -0.8598  1.0240
#
#           g-2     g-3     g-4  ...    c-90    c-91    c-92    c-93    c-94  \
# ...

# %% [markdown]
# Com uma breve instrução na aula a fonte dos dados da tabela foram contextualizados:
#
# Testagem de farmacos em cultura de células. Dessa forma pode-se supor que cada linha seja um experimento.
#
# ## Analisando as colunas
#
# ### Id:
# O id é um código único para cada experimento, tornando mais fácil a busca por um em especifico.
# ### Tratamento:

# %%
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
import matplotlib.pyplot as plt
graphic_data = dados['tratamento'].value_counts(normalize=True)
colors = ['Orange','Blue']
labels = ['Com Droga', 'Com Controle']
explode = [0,0.2]

plt.pie(graphic_data,colors=colors,labels=labels,explode=explode, autopct= '%1.1f%%', shadow=True, textprops= {'fontsize': 12})
plt.title('Proporção dos dados na coluna tratamento', {'fontsize': 14, 'fontweight': 'bold'})
# Out:
# Text(0.5, 1.0, 'Proporção dos dados na coluna tratamento')

# %% [markdown]
# A coluna tratamento apresenta dois tipos de dados: com controle e com droga, eles apresentam um ocorrência bem diferente, isso é de se esperar já que eles representam os experimentos em que houve a testagem dos farmacos e os que foram usado como grupo controle*.
#
# *Grupo controle é um participante que participará dos mesmos preparativos porém não receberá a droga, assim podendo excluir dados provenientes da preparação e manipulação do experimento.
#
# ### Tempo:

# %%
dados['tempo'].unique()
# Out:
# array([24, 72, 48], dtype=int64)

# %%
dados['tempo'].value_counts().plot.barh(title= 'Ocorrência dos dados da coluna tempo', fontsize=14, xlabel='tempo(horas)')
# Out:
# <AxesSubplot:title={'center':'Ocorrência dos dados da coluna tempo'}, ylabel='tempo(horas)'>

# %% [markdown]
# A coluna tempo apresenta três tipos de dados: 24, 48 e 72 que representam o tempo de obsevação do teste, diferente da coluna anterior, as proporções são mais próximas.
#
# ### Dose:

# %%
dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
dados['dose'].value_counts(ascending=True).plot.barh(title= 'Ocorrência dos dados na coluna dose', fontsize=14, xlabel='Doses')
# Out:
# <AxesSubplot:title={'center':'Ocorrência dos dados na coluna dose'}, ylabel='Doses'>

# %% [markdown]
# Os dados nessa coluna apresentam de duas formas: D1 e D2, eles provavelmente são as duas doses testadas.
#
# ### Droga:

# %%
dados['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %%
len(dados['droga'].unique())
# Out:
# 3289

# %% [markdown]
# Os dados da coluna drogas são bem variados, são 3289 drogas testadas, todas com o nome anonimizado, para que ocorra uma análise impessoal dos dados.
#
# ### g-x:

# %%
dados['g-0'].min()
# Out:
# -5.513

# %%
dados['g-0'].max()
# Out:
# 10.0

# %% [markdown]
# Os dados das colunas g-x são floats que variam de -10.0 a 10.0, com a explicação da especialista, são dados sobre como a droga inibe ou ativa a transcrição genica, como varia entre genes, os dados foram normalizados.

# %%
dados.rename({'droga':'composto'}, axis='columns', inplace=True)
dados
# Out:
#                  id    tratamento  tempo dose   composto      g0      g1  \
# 0      id_000644bb2     com_droga     24   D1  b68db1d53  1.0620  0.5577
# 1      id_000779bfc     com_droga     72   D1  df89a8e5a  0.0743  0.4087
# 2      id_000a6266a     com_droga     48   D1  18bb41b2c  0.6280  0.5817
# 3      id_0015fd391     com_droga     48   D1  8c7f86626 -0.5138 -0.2491
# 4      id_001626bd3     com_droga     72   D2  7cbed3131 -0.3254 -0.4009
# ...             ...           ...    ...  ...        ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  df1d0a5a1  0.1394 -0.0636
# 23810  id_fffb70c0c     com_droga     24   D2  ecf3b6b74 -1.3260  0.3478
# 23811  id_fffc1c3f4  com_controle     48   D2  cacb2b860  0.3942  0.3756
# 23812  id_fffcb9e7c     com_droga     24   D1  8b87a7a83  0.6660  0.2324
# 23813  id_ffffdd77b     com_droga     72   D1  972f41291 -0.8598  1.0240
#
#            g2      g3      g4  ...     c90     c91     c92     c93     c94  \
# ...

# %%
cod_compostos = dados['composto'].value_counts().index[:9]

# %%
import seaborn as sns
plt.figure(figsize=(10,8))
sns.set()
ax = sns.countplot(x = 'composto', data= dados.query('composto in @cod_compostos'))
ax.set_title('9 compostos mais usados', fontdict= {'fontsize': 14, 'fontweight': 'bold'})
plt.show()

# %%
plt.figure(figsize=(10,8))
ax = sns.histplot(x= 'g0', data=dados, bins=1000)
ax.set_title('Histograma dos dados em g0', fontdict= {'fontsize': 14, 'fontweight': 'bold'})
plt.show()

# %%
genes = dados.loc[:,'g0':'g771'].describe().T
genes
# Out:
#         count      mean       std     min       25%      50%       75%     max
# g0    23814.0  0.248366  1.393399  -5.513 -0.473075 -0.00885  0.525700  10.000
# g1    23814.0 -0.095684  0.812363  -5.737 -0.562200 -0.04660  0.403075   5.039
# g2    23814.0  0.152253  1.035731  -9.104 -0.437750  0.07520  0.663925   8.257
# g3    23814.0  0.081971  0.950012  -5.998 -0.429575  0.00805  0.463400  10.000
# g4    23814.0  0.057347  1.032091  -6.369 -0.470925 -0.02690  0.465375  10.000
# ...       ...       ...       ...     ...       ...      ...       ...     ...
# g767  23814.0 -0.076251  1.115477 -10.000 -0.506200  0.00990  0.511175   6.317
# g768  23814.0  0.134162  0.951264  -4.269 -0.353100  0.00540  0.409075  10.000
# g769  23814.0 -0.128018  1.230636 -10.000 -0.544600  0.00060  0.498500   5.911
# g770  23814.0 -0.219210  1.326193 -10.000 -0.554400  0.02870  0.496400  10.000
# g771  23814.0  0.101524  1.417674 -10.000 -0.523800 -0.00650  0.536950  10.000
#
# [772 rows x 8 columns]

# %%
plt.figure(figsize=(10,8))
ax = sns.histplot(x= 'mean', data= genes, bins= 100)
ax.set_title('Histograma da média dos genes', fontdict= {'fontsize': 14, 'fontweight': 'bold'})
plt.show()

# %%
celulas = dados.loc[:,'c0':].describe().T
celulas
# Out:
#        count      mean       std   min       25%      50%       75%    max
# c0   23814.0 -0.355156  1.752565 -10.0 -0.549300 -0.00900  0.448975  3.365
# c1   23814.0 -0.455359  2.004962 -10.0 -0.538425  0.00980  0.476875  3.915
# c2   23814.0 -0.480542  2.039346 -10.0 -0.550375 -0.00400  0.460575  2.970
# c3   23814.0 -0.377666  1.554583 -10.0 -0.601975 -0.03905  0.413100  2.408
# c4   23814.0 -0.493552  2.091888 -10.0 -0.559975  0.01140  0.470300  4.555
# ..       ...       ...       ...   ...       ...      ...       ...    ...
# c95  23814.0 -0.353726  1.629291 -10.0 -0.567975 -0.01025  0.444750  2.814
# c96  23814.0 -0.463485  2.059725 -10.0 -0.552575 -0.00125  0.465225  3.505
# c97  23814.0 -0.378241  1.703615 -10.0 -0.561000 -0.00680  0.446400  2.924
# c98  23814.0 -0.470252  1.834828 -10.0 -0.592600  0.01400  0.461275  3.111
# c99  23814.0 -0.301505  1.407918 -10.0 -0.562900 -0.01950  0.438650  3.805
#
# [100 rows x 8 columns]

# %%
plt.figure(figsize=(10,8))
ax = sns.histplot(x= 'mean', data= celulas, bins= 40)
ax.set_title('Histograma da média das células', fontdict= {'fontsize': 14, 'fontweight': 'bold'})
plt.show()

# %% [markdown]
# #Desafios aula 1:
#
# ###Desafio 01: Investigar porque a coluna tratamento é tão desbalanceada.
#
# ###Desafio 02: Plotar as cinco ultimas linhas da tabela.
#
# ###Desafio 03: Proporção dos dados da coluna tratamento.
#
# ###Desafio 04: Quantos tipos de droga foram investigadas.
#
# ###Desafio 05: Procurar o metodo query()
#
# ###Desafio 06: Renomear as colunas tirando o hífen
#
# ###Desafio 07: Melhorar os gráficos
#
# ###Desafio 08: Resumo da análise dos dados
#
# #Desafios aula 2:
#
# ###Desafio 01: Ordenar o gráfico countplot()
#
# ###Desafio 02: Melhorar a visualização
#
# ###Desafio 03: Plotar os histogramas com seaborn
#
# ###Desafio 04: Estudar sobre as estatisticas
#
# ###Desafio 05: Refletir sobre a manipulação dos gráficos
#
# ###Desafio 06: Fazer outras análises com o boxplot e com o histograma

# %% [markdown]
# ##Desafio 1
# Há essa discrepância porque para n varáveis em um mesmo experimento só é preciso de um grupo controle

# %% [markdown]
# ##Desafio 2

# %%
dados.tail()
# Out:
#                  id    tratamento  tempo dose   composto      g0      g1  \
# 23809  id_fffb1ceed     com_droga     24   D2  df1d0a5a1  0.1394 -0.0636
# 23810  id_fffb70c0c     com_droga     24   D2  ecf3b6b74 -1.3260  0.3478
# 23811  id_fffc1c3f4  com_controle     48   D2  cacb2b860  0.3942  0.3756
# 23812  id_fffcb9e7c     com_droga     24   D1  8b87a7a83  0.6660  0.2324
# 23813  id_ffffdd77b     com_droga     72   D1  972f41291 -0.8598  1.0240
#
#            g2      g3      g4  ...     c90     c91     c92     c93     c94  \
# 23809 -0.1112 -0.5080 -0.4713  ...  0.1969  0.0262 -0.8121  0.3434  0.5372
# 23810 -0.3743  0.9905 -0.7178  ...  0.4286  0.4426  0.0423 -0.3195 -0.8086
# 23811  0.3109 -0.7389  0.5505  ...  0.5409  0.3755  0.7343  0.2807  0.4116
# 23812  0.4392  0.2044  0.8531  ... -0.1105  0.4258 -0.2012  0.1506  1.5230
# 23813 -0.1361  0.7952 -0.3611  ... -3.3890 -1.7450 -6.6300 -4.0950 -7.3860
#
#           c95     c96     c97     c98     c99
# ...

# %% [markdown]
# ##Desafio 3

# %%
dados['tratamento'].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %% [markdown]
# ##Desafio 4

# %%
len(dados['composto'].unique())
# Out:
# 3289

# %% [markdown]
# ##Desafio 5

# %%
dados_filtrados = dados.query('`g-0` > 0', inplace = False)
dados_filtrados
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\computation\scope.py in resolve(self, key, is_local)
#     200             if self.has_resolvers:
# --> 201                 return self.resolvers[key]
#     202
#
# ~\AppData\Local\Programs\Python\Python39\lib\collections\__init__.py in __getitem__(self, key)
#     940                 pass
# --> 941         return self.__missing__(key)            # support subclasses that define __missing__
#     942
#
# ~\AppData\Local\Programs\Python\Python39\lib\collections\__init__.py in __missing__(self, key)
#     932     def __missing__(self, key):
# --> 933         raise KeyError(key)
#     934
#
# KeyError: 'BACKTICK_QUOTED_STRING_g_MINUS_0'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %% [markdown]
# ##Desafio 6

# %%
# new_labels = {}
# for column in dados.columns:
#     new_labels[column] = column.replace('-','')
# dados.rename(new_labels, axis= 'columns')
dados.columns = dados.columns.str.replace('-','')
dados
# Out:
#                  id    tratamento  tempo dose      droga      g0      g1  \
# 0      id_000644bb2     com_droga     24   D1  b68db1d53  1.0620  0.5577
# 1      id_000779bfc     com_droga     72   D1  df89a8e5a  0.0743  0.4087
# 2      id_000a6266a     com_droga     48   D1  18bb41b2c  0.6280  0.5817
# 3      id_0015fd391     com_droga     48   D1  8c7f86626 -0.5138 -0.2491
# 4      id_001626bd3     com_droga     72   D2  7cbed3131 -0.3254 -0.4009
# ...             ...           ...    ...  ...        ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  df1d0a5a1  0.1394 -0.0636
# 23810  id_fffb70c0c     com_droga     24   D2  ecf3b6b74 -1.3260  0.3478
# 23811  id_fffc1c3f4  com_controle     48   D2  cacb2b860  0.3942  0.3756
# 23812  id_fffcb9e7c     com_droga     24   D1  8b87a7a83  0.6660  0.2324
# 23813  id_ffffdd77b     com_droga     72   D1  972f41291 -0.8598  1.0240
#
#            g2      g3      g4  ...     c90     c91     c92     c93     c94  \
# ...

# %% [markdown]
# ##Desafios 7 e 8
# Feitos durante a nálise dos dados antes dos desafios.
